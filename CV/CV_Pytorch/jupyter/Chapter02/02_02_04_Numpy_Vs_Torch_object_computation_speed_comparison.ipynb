# %% [markdown]
# <a href="https://colab.research.google.com/github/PacktPublishing/Hands-On-Computer-Vision-with-PyTorch/blob/master/Chapter02/Numpy_Vs_Torch_object_computation_speed_comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
x = torch.rand(1, 6400)
y = torch.rand(6400, 5000)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
assert device == 'cuda', "This exercise assumes the notebook is on a GPU machine"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 device = 'cuda' if torch.cuda.is_available() else 'cpu'
# ----> 2 assert device == 'cuda', "This exercise assumes the notebook is on a GPU machine"
#
# AssertionError: This exercise assumes the notebook is on a GPU machine

# %%
x, y = x.to(device), y.to(device)

# %%
# %timeit z=(x@y)
# Out:
# 7.49 ms ± 146 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
x, y = x.cpu(), y.cpu()
# %timeit z=(x@y)
# Out:
# 7.38 ms ± 61.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
import numpy as np
x = np.random.random((1, 6400))
y = np.random.random((6400, 5000))
# %timeit z = np.matmul(x,y)
# Out:
# 17.6 ms ± 1.04 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
